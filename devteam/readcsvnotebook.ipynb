# %% [markdown]
# ### reading csv file

# %%
df= spark.read.csv("/Volumes/customers_catalog/customersschema/filesstorage/csv/customers-1000.csv",header=True,inferSchema=True)
df.display()

# %%
df= spark.read.csv("/Volumes/customers_catalog/customersschema/filesstorage/csv/customers-1000.csv",header=True,inferSchema=True)
df.show(10)

# %%
df = spark.read.csv("/Volumes/customers_catalog/customersschema/filesstorage/csv/customers-1000.csv",header=True,inferSchema=True)
display(df.limit(10))

# %% [markdown]
# ##Reading parquet files

# %%
df_parquet = spark.read.parquet("/Volumes/customers_catalog/customersschema/filesstorage/parquet/titanic.parquet",header=True,inferSchema=True)
df_parquet.display()

# %%
df_parquet = spark.read.parquet("/Volumes/customers_catalog/customersschema/filesstorage/parquet/titanic.parquet",header=True,inferSchema=True)
display(df_parquet.limit(10))

# %%
df_csv = spark.read.format("csv").option("header","true").option("inferSchema","true").load("/Volumes/customers_catalog/customersschema/filesstorage/csv/customers-1000.csv")
display(df_csv)

# %%
filepath = "/Volumes/customers_catalog/customersschema/filesstorage/csv/customers-1000.csv"
df_csv = spark.read.format("csv").option("header","true").option("inferSchema","true").load(filepath)
display(df_csv.limit(10))

# %%
filepath = "/Volumes/customers_catalog/customersschema/filesstorage/parquet/weather.parquet"
df_weather = spark.read.format("parquet").option("header","true").option("inferschema","true").load(filepath)
display(df_weather.limit(100))

# %% [markdown]
# ## Reading json file

# %%
jsonfilepath = "/Volumes/customers_catalog/customersschema/filesstorage/json/currencies.json"
df_json = spark.read.format("json")\
        .option("multiLine","true")\
        .option("inferSchema","true")\
        .load(jsonfilepath)
display(df_json)

# %%
jsonfilepath = "/Volumes/customers_catalog/customersschema/filesstorage/json/holidays-us.json"
            spark.read.format("json")\
                    .option("multiLine","true")\
                    .option("inferSchema","true")\
                    .load(jsonfilepath).display()
#display(df_json)
