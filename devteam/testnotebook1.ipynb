# %%
print("Hello this is first notebook")
#dbutils.fs.mount(
#source = "wasbs://global@cloudpandithdevblob.blob.core.windows.net",
#mount_point = "/mnt/global",
#extra_configs = {"fs.azure.account.key.cloudpandithdevblob.blob.core.windows.net": "XoTsqtENyXEYPywRNL8eRTrryq3YEeGRHVbY86uCmqI2/JMdeSuL1pt27RFsMSVdMej/I0y4yYi1+ASt0c1V9A=="}
#dbutils.fs.unmount("/mnt/global")
